# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd /gdrive/My Drive/ANN2
# Out:
# /gdrive/My Drive/ANN2

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import warnings
import logging

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.9.2

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
import warnings
import logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)
tf.get_logger().setLevel('INFO')
tf.autograph.set_verbosity(0)

tf.get_logger().setLevel(logging.ERROR)
tf.get_logger().setLevel('ERROR')
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
label_mapping =  {'Wish':0,        #0
          'Another':1,      #1
          'Comfortably':2,  #2
          'Money':3,        #3
          'Breathe':4,      #4
          'Time':5,         #5
          'Brain':6,        #6
          'Echoes':7,       #7
          'Wearing':8,      #8
          'Sorrow':9,       #9
          'Hey':10,          #10
          'Shine':11}      #11

# %%
x_train = np.load("Dataset/x_train.npy")
y_train = np.load("Dataset/y_train.npy")
#dataset.shape, labels.shape

# %%
#x_train, y_train = shuffle(dataset, labels, random_state=0)
#indices = np.arange(dataset.shape[0])
#np.random.shuffle(indices)

#x_train = dataset[indices]
#y_train = labels[indices]

#x_train.shape, y_train.shape

# %%
y_train = tfk.utils.to_categorical(y_train)
x_train.shape, y_train.shape
# Out:
# ((2429, 36, 6), (2429, 12))

# %%
#x_train = np.asarray([dataset[i, :, :] for i in range(int(dataset.shape[0] * 0.7))])
#x_val = np.asarray([dataset[i, :, :] for i in range(int(dataset.shape[0] * 0.7), int(len(dataset) * 0.9))])
#x_test = np.asarray([dataset[i, :, :] for i in range(int(dataset.shape[0] * 0.9), len(dataset))])
#x_train.shape, x_val.shape, x_test.shape

# %%
#y_train = np.asarray([labels[i, :] for i in range(int(labels.shape[0] * 0.7))])
#y_val = np.asarray([labels[i, :] for i in range(int(labels.shape[0] * 0.7), int(len(labels) * 0.9))])
#y_test = np.asarray([labels[i, :] for i in range(int(labels.shape[0] * 0.9), len(labels))])
#y_train.shape, y_val.shape, y_test.shape

# %%
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.05, random_state=seed, shuffle=True, stratify=y_train)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=seed, shuffle=True, stratify=y_train)
x_train.shape, x_val.shape, x_test.shape
# Out:
# ((1845, 36, 6), (462, 36, 6), (122, 36, 6))

# %%
#for i in range(0, 6):
#  data = x_train[:, :, i]
#  min = data.min(axis=(1), keepdims=True)
#  max = data.max(axis=(1), keepdims=True)
#  x_train[:, :, i] = (x_train[:, :, i] - min)/(max - min)

# %%
#scaler = StandardScaler()
#x_train = scaler.fit_transform(x_train.reshape(-1, x_train.shape[-1])).reshape(x_train.shape)
#x_train.shape

# %%
#scaler = MinMaxScaler()
#x_train = scaler.fit_transform(x_train.reshape(-1, x_train.shape[-1])).reshape(x_train.shape)
#x_train.shape

# %%
#x_train_min = x_train.min(axis=(2), keepdims=True)
#x_train_max = x_train.max(axis=(2), keepdims=True)
#(v - v_min)/(v_max - v_min)

#x_train = (x_train - x_train_min)/(x_train_max - x_train_min)
#x_val = (x_val - x_train_min)/(x_train_max - x_train_min)
#x_test = (x_test - x_train_min)/(x_train_max - x_train_min)
#x_train
#x_train_min, x_train_max

# %%
input_shape = x_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 8
epochs = 400

# %%
def build_BiLSTM_classifier(input_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    conv1 = tfkl.Conv1D(
        filters=64,
        kernel_size=3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed)
    )(input_layer)
    pool1 = tfkl.MaxPooling1D(pool_size=2)(conv1)
    conv2 = tfkl.Conv1D(
        filters=128,
        kernel_size=3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed)
    )(pool1)
    bilstm = tfkl.Bidirectional(tfkl.GRU(256, return_sequences=True, kernel_regularizer=tf.keras.regularizers.L1(1e-2), dropout=0.3))(conv2)
    bilstm = tfkl.Bidirectional(tfkl.GRU(256, kernel_regularizer=tf.keras.regularizers.L1(1e-2), dropout=0.3))(bilstm)
    #dropout = tfkl.Dropout(.2, seed=seed)(bilstm)

    # Classifier
    classifier_layer = tfkl.Dense(units=512, name='Classifier', kernel_initializer=tfk.initializers.HeUniform(seed), activation='relu')(bilstm)
    dropout = tfkl.Dropout(0.2, seed=seed)(classifier_layer)
    output_layer = tfkl.Dense(units=12, activation='softmax', kernel_initializer=tfk.initializers.GlorotUniform(seed), name='output_layer')(dropout)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(learning_rate=0.0001), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_BiLSTM_classifier(input_shape)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 36, 6)]           0
#
#  conv1d_2 (Conv1D)           (None, 36, 64)            1216
#
#  max_pooling1d_1 (MaxPooling  (None, 18, 64)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 18, 128)           24704
#
#  bidirectional_2 (Bidirectio  (None, 18, 512)          592896
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 512)              1182720
#  nal)
#
#  Classifier (Dense)          (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  output_layer (Dense)        (None, 12)                6156
#
# =================================================================
# Total params: 2,070,348
# Trainable params: 2,070,348
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (x_val, y_val),
    #validation_split=.2,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True)
        #tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/400
# 231/231 [==============================] - 10s 17ms/step - loss: 267.2300 - accuracy: 0.3035 - val_loss: 191.7143 - val_accuracy: 0.3788
# Epoch 2/400
# 231/231 [==============================] - 3s 12ms/step - loss: 135.8425 - accuracy: 0.3561 - val_loss: 88.3963 - val_accuracy: 0.4286
# Epoch 3/400
# 231/231 [==============================] - 3s 12ms/step - loss: 59.9494 - accuracy: 0.3978 - val_loss: 40.1747 - val_accuracy: 0.4524
# Epoch 4/400
# 231/231 [==============================] - 3s 12ms/step - loss: 32.2257 - accuracy: 0.4282 - val_loss: 26.0481 - val_accuracy: 0.4740
# Epoch 5/400
# 231/231 [==============================] - 3s 12ms/step - loss: 22.5734 - accuracy: 0.4401 - val_loss: 19.9347 - val_accuracy: 0.3268
# Epoch 6/400
# 231/231 [==============================] - 3s 12ms/step - loss: 17.7044 - accuracy: 0.4331 - val_loss: 15.7724 - val_accuracy: 0.5411
# Epoch 7/400
# 231/231 [==============================] - 3s 12ms/step - loss: 14.4791 - accuracy: 0.4526 - val_loss: 13.0904 - val_accuracy: 0.5087
# Epoch 8/400
# 231/231 [==============================] - 3s 12ms/step - loss: 12.0947 - accuracy: 0.4596 - val_loss: 10.9839 - val_accuracy: 0.5238
# Epoch 9/400
# 231/231 [==============================] - 3s 12ms/step - loss: 10.2258 - accuracy: 0.4634 - val_loss: 9.3304 - val_accuracy: 0.5411
# Epoch 10/400
# 231/231 [==============================] - 3s 12ms/step - loss: 8.7486 - accuracy: 0.4889 - val_loss: 8.1289 - val_accuracy: 0.5303
# Epoch 11/400
# 231/231 [==============================] - 3s 12ms/step - loss: 7.6077 - accuracy: 0.4856 - val_loss: 7.2368 - val_accuracy: 0.5043
# Epoch 12/400
# 231/231 [==============================] - 3s 12ms/step - loss: 6.6976 - accuracy: 0.4818 - val_loss: 6.2725 - val_accuracy: 0.5216
# Epoch 13/400
# 231/231 [==============================] - 3s 12ms/step - loss: 5.9244 - accuracy: 0.5079 - val_loss: 5.5803 - val_accuracy: 0.5541
# Epoch 14/400
# 231/231 [==============================] - 3s 12ms/step - loss: 5.3655 - accuracy: 0.4981 - val_loss: 5.0929 - val_accuracy: 0.5606
# Epoch 15/400
# 231/231 [==============================] - 3s 12ms/step - loss: 4.8491 - accuracy: 0.5236 - val_loss: 4.5867 - val_accuracy: 0.5714
# Epoch 16/400
# 231/231 [==============================] - 3s 12ms/step - loss: 4.4575 - accuracy: 0.5117 - val_loss: 4.2292 - val_accuracy: 0.5649
# Epoch 17/400
# 231/231 [==============================] - 3s 12ms/step - loss: 4.1436 - accuracy: 0.5133 - val_loss: 4.0346 - val_accuracy: 0.5541
# Epoch 18/400
# 231/231 [==============================] - 3s 12ms/step - loss: 3.8311 - accuracy: 0.5257 - val_loss: 3.8757 - val_accuracy: 0.5628
# Epoch 19/400
# 231/231 [==============================] - 3s 12ms/step - loss: 3.6744 - accuracy: 0.5220 - val_loss: 3.4010 - val_accuracy: 0.5887
# Epoch 20/400
# 231/231 [==============================] - 3s 12ms/step - loss: 3.4110 - accuracy: 0.5279 - val_loss: 3.3928 - val_accuracy: 0.5216
# Epoch 21/400
# 231/231 [==============================] - 3s 12ms/step - loss: 3.2531 - accuracy: 0.5268 - val_loss: 3.2147 - val_accuracy: 0.4697
# Epoch 22/400
# 231/231 [==============================] - 3s 12ms/step - loss: 3.1382 - accuracy: 0.5214 - val_loss: 3.0198 - val_accuracy: 0.5758
# Epoch 23/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.9776 - accuracy: 0.5404 - val_loss: 3.0400 - val_accuracy: 0.5541
# Epoch 24/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.9027 - accuracy: 0.5442 - val_loss: 2.9092 - val_accuracy: 0.5736
# Epoch 25/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.7754 - accuracy: 0.5463 - val_loss: 2.6669 - val_accuracy: 0.5693
# Epoch 26/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.6818 - accuracy: 0.5659 - val_loss: 2.5511 - val_accuracy: 0.5801
# Epoch 27/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.6330 - accuracy: 0.5491 - val_loss: 2.4827 - val_accuracy: 0.5801
# Epoch 28/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.5447 - accuracy: 0.5561 - val_loss: 2.5186 - val_accuracy: 0.5952
# Epoch 29/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.4936 - accuracy: 0.5696 - val_loss: 2.4551 - val_accuracy: 0.5671
# Epoch 30/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.4487 - accuracy: 0.5686 - val_loss: 2.4691 - val_accuracy: 0.5996
# Epoch 31/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.4556 - accuracy: 0.5789 - val_loss: 2.4856 - val_accuracy: 0.5758
# Epoch 32/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.4094 - accuracy: 0.5713 - val_loss: 2.3148 - val_accuracy: 0.6126
# Epoch 33/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.2788 - accuracy: 0.5962 - val_loss: 2.3832 - val_accuracy: 0.5974
# Epoch 34/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.2697 - accuracy: 0.6011 - val_loss: 2.2436 - val_accuracy: 0.6169
# Epoch 35/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.2451 - accuracy: 0.6000 - val_loss: 2.3899 - val_accuracy: 0.5909
# Epoch 36/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.2695 - accuracy: 0.6043 - val_loss: 2.3404 - val_accuracy: 0.5779
# Epoch 37/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.2242 - accuracy: 0.5995 - val_loss: 2.3984 - val_accuracy: 0.5844
# Epoch 38/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.2309 - accuracy: 0.6016 - val_loss: 2.3157 - val_accuracy: 0.6126
# Epoch 39/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.1000 - accuracy: 0.6255 - val_loss: 2.2461 - val_accuracy: 0.6082
# Epoch 40/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.1790 - accuracy: 0.6070 - val_loss: 2.2708 - val_accuracy: 0.6061
# Epoch 41/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.1333 - accuracy: 0.6136 - val_loss: 2.2571 - val_accuracy: 0.5974
# Epoch 42/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.1640 - accuracy: 0.6146 - val_loss: 2.2454 - val_accuracy: 0.5931
# Epoch 43/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.0480 - accuracy: 0.6282 - val_loss: 2.2100 - val_accuracy: 0.5996
# Epoch 44/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.0707 - accuracy: 0.6195 - val_loss: 2.3452 - val_accuracy: 0.6017
# Epoch 45/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.0737 - accuracy: 0.6244 - val_loss: 2.1734 - val_accuracy: 0.6299
# Epoch 46/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.0107 - accuracy: 0.6390 - val_loss: 2.2417 - val_accuracy: 0.6190
# Epoch 47/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.9905 - accuracy: 0.6358 - val_loss: 2.2971 - val_accuracy: 0.6039
# Epoch 48/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.0717 - accuracy: 0.6352 - val_loss: 2.1963 - val_accuracy: 0.6212
# Epoch 49/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.9978 - accuracy: 0.6591 - val_loss: 2.0849 - val_accuracy: 0.6407
# Epoch 50/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.0556 - accuracy: 0.6260 - val_loss: 2.2433 - val_accuracy: 0.6320
# Epoch 51/400
# 231/231 [==============================] - 3s 12ms/step - loss: 2.0048 - accuracy: 0.6314 - val_loss: 2.1153 - val_accuracy: 0.6212
# Epoch 52/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.8755 - accuracy: 0.6618 - val_loss: 2.3180 - val_accuracy: 0.5974
# Epoch 53/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.9698 - accuracy: 0.6547 - val_loss: 2.1118 - val_accuracy: 0.6342
# Epoch 54/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.9246 - accuracy: 0.6650 - val_loss: 2.2217 - val_accuracy: 0.6104
# Epoch 55/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.9458 - accuracy: 0.6520 - val_loss: 2.0227 - val_accuracy: 0.6429
# Epoch 56/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.9652 - accuracy: 0.6618 - val_loss: 2.1320 - val_accuracy: 0.6234
# Epoch 57/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.9627 - accuracy: 0.6645 - val_loss: 2.1211 - val_accuracy: 0.6234
# Epoch 58/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.9297 - accuracy: 0.6623 - val_loss: 2.1083 - val_accuracy: 0.6255
# Epoch 59/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.8985 - accuracy: 0.6607 - val_loss: 2.0464 - val_accuracy: 0.6212
# Epoch 60/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.9490 - accuracy: 0.6585 - val_loss: 2.3189 - val_accuracy: 0.6234
# Epoch 61/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.8971 - accuracy: 0.6705 - val_loss: 2.1264 - val_accuracy: 0.6494
# Epoch 62/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.9731 - accuracy: 0.6634 - val_loss: 2.1298 - val_accuracy: 0.6126
# Epoch 63/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.8408 - accuracy: 0.6775 - val_loss: 2.0742 - val_accuracy: 0.6342
# Epoch 64/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.8458 - accuracy: 0.6737 - val_loss: 2.0234 - val_accuracy: 0.6472
# Epoch 65/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.8415 - accuracy: 0.6894 - val_loss: 2.2352 - val_accuracy: 0.5866
# Epoch 66/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.8648 - accuracy: 0.6764 - val_loss: 2.1365 - val_accuracy: 0.5952
# Epoch 67/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.7467 - accuracy: 0.6921 - val_loss: 2.3643 - val_accuracy: 0.5714
# Epoch 68/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.9029 - accuracy: 0.6764 - val_loss: 2.1877 - val_accuracy: 0.6082
# Epoch 69/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.8096 - accuracy: 0.6921 - val_loss: 2.1302 - val_accuracy: 0.6169
# Epoch 70/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.7950 - accuracy: 0.6976 - val_loss: 2.0582 - val_accuracy: 0.6450
# Epoch 71/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.8120 - accuracy: 0.6954 - val_loss: 2.2003 - val_accuracy: 0.6385
# Epoch 72/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.7959 - accuracy: 0.6949 - val_loss: 2.0455 - val_accuracy: 0.6255
# Epoch 73/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.7815 - accuracy: 0.7079 - val_loss: 2.1862 - val_accuracy: 0.6472
# Epoch 74/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.8420 - accuracy: 0.6911 - val_loss: 2.0981 - val_accuracy: 0.6234
# Epoch 75/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.7738 - accuracy: 0.7073 - val_loss: 2.0379 - val_accuracy: 0.6320
# Epoch 76/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.7552 - accuracy: 0.7051 - val_loss: 2.1474 - val_accuracy: 0.6299
# Epoch 77/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.8167 - accuracy: 0.6986 - val_loss: 2.1384 - val_accuracy: 0.6342
# Epoch 78/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.7640 - accuracy: 0.7089 - val_loss: 2.2382 - val_accuracy: 0.6212
# Epoch 79/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.7627 - accuracy: 0.7176 - val_loss: 2.2287 - val_accuracy: 0.6277
# Epoch 80/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.7617 - accuracy: 0.7117 - val_loss: 2.0713 - val_accuracy: 0.6299
# Epoch 81/400
# 231/231 [==============================] - 3s 12ms/step - loss: 1.7936 - accuracy: 0.6938 - val_loss: 2.1611 - val_accuracy: 0.6169

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

#plt.figure(figsize=(18,3))
#plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
#plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
#plt.legend()
#plt.grid(alpha=.3)
#plt.show()

# %%
model.save("Models/Model4")
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, gru_cell_7_layer_call_fn, gru_cell_7_layer_call_and_return_conditional_losses, gru_cell_8_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.

# %%
predictions = model.predict(x_test)
predictions.shape
# Out:
# 4/4 [==============================] - 1s 6ms/step
# (122, 12)

# %%
#Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.6148
# Precision: 0.4473
# Recall: 0.3886
# F1: 0.3972
