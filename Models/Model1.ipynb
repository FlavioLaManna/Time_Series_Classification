# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/My Drive/ANN2
# Out:
# /gdrive/My Drive/ANN2

# %%
# !pip install tsaug
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tsaug
#   Downloading tsaug-0.2.1-py3-none-any.whl (32 kB)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.8/dist-packages (from tsaug) (1.21.6)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.8/dist-packages (from tsaug) (1.7.3)
# Installing collected packages: tsaug
# Successfully installed tsaug-0.2.1

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tsaug import TimeWarp, AddNoise, Quantize, Drift, Reverse
import pickle
import warnings
import logging

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.9.2

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
import warnings
import logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)
tf.get_logger().setLevel('INFO')
tf.autograph.set_verbosity(0)

tf.get_logger().setLevel(logging.ERROR)
tf.get_logger().setLevel('ERROR')
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
label_mapping =  {'Wish':0,        #0
          'Another':1,      #1
          'Comfortably':2,  #2
          'Money':3,        #3
          'Breathe':4,      #4
          'Time':5,         #5
          'Brain':6,        #6
          'Echoes':7,       #7
          'Wearing':8,      #8
          'Sorrow':9,       #9
          'Hey':10,          #10
          'Shine':11}      #11

# %%
x_train = np.load("Dataset/x_train.npy")
y_train = np.load("Dataset/y_train.npy")
#dataset.shape, labels.shape

# %%
#from sklearn.utils import class_weight

#class_weights = class_weight.compute_class_weight('balanced', classes = np.unique(y_train), y = y_train)

#class_weights = (class_weights - class_weights.mean()) / (class_weights.std())
#class_weights = class_weights + abs(class_weights.min()) + 1
#class_weights = [0.5 * w if w > 2 else w for w in class_weights ] 

#class_weights = {k: v for k, v in enumerate(class_weights)}
#class_weights

#class_weights = {0: 2.,
#                 1: 1.8,
#                 2: 1.,
#                 3: 2.,
#                 4: 5.,
#                 5: 3.,
#                 6: 1.3,
#                 7: 3.5,
#                 8: 1,
#                 9: 1.5,
#                 10: 1.3,
#                 11: 2.5}

# %%
#x_train, y_train = shuffle(dataset, labels, random_state=0)
#indices = np.arange(dataset.shape[0])
#np.random.shuffle(indices)

#x_train = dataset[indices]
#y_train = labels[indices]

#x_train.shape, y_train.shape

# %%
y_train = tfk.utils.to_categorical(y_train)
x_train.shape, y_train.shape
# Out:
# ((2429, 36, 6), (2429, 12))

# %%
#scaler1 = MinMaxScaler()
#x_train = scaler1.fit_transform(x_train.reshape(-1, x_train.shape[-1])).reshape(x_train.shape)
#x_train.shape

#scaler2 = StandardScaler()
#x_train = scaler2.fit_transform(x_train.reshape(-1, x_train.shape[-1])).reshape(x_train.shape)
#x_train.shape

scaler2 = RobustScaler()
x_train = scaler2.fit_transform(x_train.reshape(-1, x_train.shape[-1])).reshape(x_train.shape)
#x_val = scaler.transform(x_val.reshape(-1, x_val.shape[-1])).reshape(x_val.shape)
#x_test = scaler.transform(x_test.reshape(-1, x_test.shape[-1])).reshape(x_test.shape)
#x_train.shape, x_val.shape, x_test.shape

# %%
#with open('minmax_scaler.pkl', 'wb') as scaler_file:
# pickle.dump(scaler1, scaler_file)

with open('robust_scaler.pkl', 'wb') as scaler_file:
 pickle.dump(scaler2, scaler_file)

#with open('standard_scaler.pkl', 'wb') as scaler_file:
#  pickle.dump(scaler2, scaler_file)

# %%
#x_train = np.asarray([dataset[i, :, :] for i in range(int(dataset.shape[0] * 0.7))])
#x_val = np.asarray([dataset[i, :, :] for i in range(int(dataset.shape[0] * 0.7), int(len(dataset) * 0.9))])
#x_test = np.asarray([dataset[i, :, :] for i in range(int(dataset.shape[0] * 0.9), len(dataset))])
#x_train.shape, x_val.shape, x_test.shape

# %%
#y_train = np.asarray([labels[i, :] for i in range(int(labels.shape[0] * 0.7))])
#y_val = np.asarray([labels[i, :] for i in range(int(labels.shape[0] * 0.7), int(len(labels) * 0.9))])
#y_test = np.asarray([labels[i, :] for i in range(int(labels.shape[0] * 0.9), len(labels))])
#y_train.shape, y_val.shape, y_test.shape

# %%
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.05, random_state=seed, shuffle=True, stratify=y_train)

aug_size = 5
my_augmenter = (
    TimeWarp() * aug_size  # random time warping 5 times in parallel
    + AddNoise(scale=(0.01, 0.05)) @ 0.5  # with 50% probability, add random noise up to 1% - 5%
    + Quantize(n_levels=[5, 10, 15])  # random quantize to 10-, 20-, or 30- level sets
    + Drift(max_drift=(0.1, 0.2)) @ 0.6  # with 80% probability, random drift the signal up to 10% - 50%
    + Reverse() @ 0.5  # with 50% probability, reverse the sequence
)

x_train_aug = my_augmenter.augment(x_train)

num_samples_augmented = aug_size*x_train.shape[0]

assert(x_train_aug.shape[0] == num_samples_augmented)

x_train = np.append(x_train, x_train_aug, axis=0)

# Appending the labels of the augmented samples to the labels in the train set
y_train_aug = [y_train[i] for i in range(y_train.shape[0]) for j in range(aug_size)]
y_train = np.append(y_train, y_train_aug, axis=0)

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=seed, shuffle=True, stratify=y_train)
x_train.shape, x_val.shape, x_test.shape
# Out:
# ((11073, 36, 6), (2769, 36, 6), (122, 36, 6))

# %%
#for i in range(0, 6):
#  data = x_train[:, :, i]
#  min = data.min(axis=(1), keepdims=True)
#  max = data.max(axis=(1), keepdims=True)
#  x_train[:, :, i] = (x_train[:, :, i] - min)/(max - min)

# %%
#x_train_min = x_train.min(axis=(2), keepdims=True)
#x_train_max = x_train.max(axis=(2), keepdims=True)
#(v - v_min)/(v_max - v_min)

#x_train = (x_train - x_train_min)/(x_train_max - x_train_min)
#x_val = (x_val - x_train_min)/(x_train_max - x_train_min)
#x_test = (x_test - x_train_min)/(x_train_max - x_train_min)
#x_train
#x_train_min, x_train_max

# %%
input_shape = x_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 8
epochs = 1000

# %%
def build_1DCNN_classifier(input_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    conv1 = tfkl.Conv1D(
        filters=64,
        kernel_size=3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed)
    )(input_layer)
    pool1 = tfkl.MaxPooling1D(pool_size=2)(conv1)
    conv2 = tfkl.Conv1D(
        filters=128,
        kernel_size=3,
        padding = 'same',
        activation = 'relu',
        kernel_initializer = tfk.initializers.HeUniform(seed)
    )(pool1)
    gap = tfkl.GlobalAveragePooling1D()(conv2)
    dropout = tfkl.Dropout(0.2, seed=seed)(gap)

    # Classifier
    classifier_layer = tfkl.Dense(units=512, name='Classifier', kernel_initializer=tfk.initializers.HeUniform(seed), activation='relu')(dropout)
    dropout = tfkl.Dropout(0.2, seed=seed)(classifier_layer)
    output_layer = tfkl.Dense(units=12, activation='softmax', kernel_initializer=tfk.initializers.GlorotUniform(seed), name='output_layer')(dropout)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(learning_rate=0.0001), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_1DCNN_classifier(input_shape)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 36, 6)]           0
#
#  conv1d (Conv1D)             (None, 36, 64)            1216
#
#  max_pooling1d (MaxPooling1D  (None, 18, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 18, 128)           24704
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  dropout (Dropout)           (None, 128)               0
#
#  Classifier (Dense)          (None, 512)               66048
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  output_layer (Dense)        (None, 12)                6156
#
# =================================================================
# Total params: 98,124
# Trainable params: 98,124
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (x_val, y_val),
    #class_weight = class_weights,
    #validation_split=.2,
    callbacks = [
        #tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=30, restore_best_weights=True)
        #tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 14.2450 - accuracy: 0.1999 - val_loss: 5.8311 - val_accuracy: 0.3294
# Epoch 2/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 6.5109 - accuracy: 0.3455 - val_loss: 3.4126 - val_accuracy: 0.4489
# Epoch 3/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 3.6519 - accuracy: 0.4083 - val_loss: 2.8798 - val_accuracy: 0.4540
# Epoch 4/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 2.8677 - accuracy: 0.4394 - val_loss: 2.0928 - val_accuracy: 0.4850
# Epoch 5/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 2.3101 - accuracy: 0.4627 - val_loss: 1.9296 - val_accuracy: 0.5013
# Epoch 6/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 2.0680 - accuracy: 0.4728 - val_loss: 1.9230 - val_accuracy: 0.4702
# Epoch 7/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.8235 - accuracy: 0.4832 - val_loss: 1.6097 - val_accuracy: 0.5103
# Epoch 8/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.6823 - accuracy: 0.4947 - val_loss: 1.5609 - val_accuracy: 0.5237
# Epoch 9/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 1.5967 - accuracy: 0.5056 - val_loss: 1.5102 - val_accuracy: 0.5233
# Epoch 10/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.5325 - accuracy: 0.5205 - val_loss: 1.4628 - val_accuracy: 0.5374
# Epoch 11/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.4758 - accuracy: 0.5322 - val_loss: 1.4049 - val_accuracy: 0.5497
# Epoch 12/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.3955 - accuracy: 0.5441 - val_loss: 1.3370 - val_accuracy: 0.5616
# Epoch 13/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.4183 - accuracy: 0.5514 - val_loss: 1.3436 - val_accuracy: 0.5717
# Epoch 14/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.3488 - accuracy: 0.5578 - val_loss: 1.2872 - val_accuracy: 0.5749
# Epoch 15/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.3301 - accuracy: 0.5705 - val_loss: 1.2304 - val_accuracy: 0.5984
# Epoch 16/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 1.2789 - accuracy: 0.5792 - val_loss: 1.2447 - val_accuracy: 0.5930
# Epoch 17/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.2817 - accuracy: 0.5856 - val_loss: 1.2411 - val_accuracy: 0.6038
# Epoch 18/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.2263 - accuracy: 0.5988 - val_loss: 1.1747 - val_accuracy: 0.6194
# Epoch 19/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.2622 - accuracy: 0.5941 - val_loss: 1.1942 - val_accuracy: 0.6092
# Epoch 20/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 1.1893 - accuracy: 0.6070 - val_loss: 1.1985 - val_accuracy: 0.6262
# Epoch 21/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 1.1680 - accuracy: 0.6142 - val_loss: 1.1499 - val_accuracy: 0.6331
# Epoch 22/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 1.1432 - accuracy: 0.6188 - val_loss: 1.0773 - val_accuracy: 0.6334
# Epoch 23/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.1381 - accuracy: 0.6183 - val_loss: 1.0986 - val_accuracy: 0.6280
# Epoch 24/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.1111 - accuracy: 0.6251 - val_loss: 1.0924 - val_accuracy: 0.6389
# Epoch 25/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.1267 - accuracy: 0.6265 - val_loss: 1.1490 - val_accuracy: 0.6331
# Epoch 26/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.0960 - accuracy: 0.6282 - val_loss: 1.0701 - val_accuracy: 0.6396
# Epoch 27/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.0821 - accuracy: 0.6330 - val_loss: 1.0749 - val_accuracy: 0.6436
# Epoch 28/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.0733 - accuracy: 0.6353 - val_loss: 1.0468 - val_accuracy: 0.6482
# Epoch 29/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.0537 - accuracy: 0.6443 - val_loss: 1.0983 - val_accuracy: 0.6511
# Epoch 30/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.0399 - accuracy: 0.6475 - val_loss: 1.0269 - val_accuracy: 0.6508
# Epoch 31/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.0280 - accuracy: 0.6479 - val_loss: 1.0801 - val_accuracy: 0.6454
# Epoch 32/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.0418 - accuracy: 0.6505 - val_loss: 1.0129 - val_accuracy: 0.6598
# Epoch 33/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.0198 - accuracy: 0.6546 - val_loss: 1.0065 - val_accuracy: 0.6602
# Epoch 34/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.9923 - accuracy: 0.6584 - val_loss: 0.9995 - val_accuracy: 0.6609
# Epoch 35/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 1.0163 - accuracy: 0.6580 - val_loss: 1.0374 - val_accuracy: 0.6587
# Epoch 36/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 1.0022 - accuracy: 0.6643 - val_loss: 0.9863 - val_accuracy: 0.6656
# Epoch 37/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 1.0056 - accuracy: 0.6640 - val_loss: 0.9791 - val_accuracy: 0.6699
# Epoch 38/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.9673 - accuracy: 0.6687 - val_loss: 0.9785 - val_accuracy: 0.6714
# Epoch 39/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.9651 - accuracy: 0.6671 - val_loss: 0.9991 - val_accuracy: 0.6746
# Epoch 40/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.9585 - accuracy: 0.6752 - val_loss: 0.9577 - val_accuracy: 0.6761
# Epoch 41/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.9215 - accuracy: 0.6797 - val_loss: 0.9574 - val_accuracy: 0.6789
# Epoch 42/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.9392 - accuracy: 0.6780 - val_loss: 0.9764 - val_accuracy: 0.6746
# Epoch 43/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.9271 - accuracy: 0.6780 - val_loss: 0.9472 - val_accuracy: 0.6847
# Epoch 44/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.9022 - accuracy: 0.6856 - val_loss: 0.9360 - val_accuracy: 0.6844
# Epoch 45/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.9181 - accuracy: 0.6799 - val_loss: 0.9344 - val_accuracy: 0.6815
# Epoch 46/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.9318 - accuracy: 0.6820 - val_loss: 0.9520 - val_accuracy: 0.6858
# Epoch 47/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.9173 - accuracy: 0.6830 - val_loss: 0.9320 - val_accuracy: 0.6844
# Epoch 48/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.8968 - accuracy: 0.6882 - val_loss: 0.9549 - val_accuracy: 0.6779
# Epoch 49/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.8879 - accuracy: 0.6918 - val_loss: 0.9204 - val_accuracy: 0.6873
# Epoch 50/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.8965 - accuracy: 0.6923 - val_loss: 0.9162 - val_accuracy: 0.6880
# Epoch 51/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.8750 - accuracy: 0.6946 - val_loss: 0.9278 - val_accuracy: 0.6891
# Epoch 52/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.8843 - accuracy: 0.6967 - val_loss: 0.9026 - val_accuracy: 0.6901
# Epoch 53/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.8806 - accuracy: 0.7014 - val_loss: 0.9143 - val_accuracy: 0.6981
# Epoch 54/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.8564 - accuracy: 0.7004 - val_loss: 0.9065 - val_accuracy: 0.6992
# Epoch 55/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.8431 - accuracy: 0.7056 - val_loss: 0.8901 - val_accuracy: 0.7024
# Epoch 56/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.8448 - accuracy: 0.7078 - val_loss: 0.8976 - val_accuracy: 0.7013
# Epoch 57/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.8515 - accuracy: 0.7072 - val_loss: 0.8954 - val_accuracy: 0.6927
# Epoch 58/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.8552 - accuracy: 0.7035 - val_loss: 0.8985 - val_accuracy: 0.7039
# Epoch 59/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.8564 - accuracy: 0.7124 - val_loss: 0.8913 - val_accuracy: 0.7035
# Epoch 60/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.8341 - accuracy: 0.7091 - val_loss: 0.8809 - val_accuracy: 0.7042
# Epoch 61/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.8187 - accuracy: 0.7131 - val_loss: 0.8924 - val_accuracy: 0.7082
# Epoch 62/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.8158 - accuracy: 0.7178 - val_loss: 0.8740 - val_accuracy: 0.7049
# Epoch 63/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.8069 - accuracy: 0.7203 - val_loss: 0.8645 - val_accuracy: 0.7154
# Epoch 64/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.8103 - accuracy: 0.7163 - val_loss: 0.8824 - val_accuracy: 0.7075
# Epoch 65/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.8099 - accuracy: 0.7229 - val_loss: 0.8680 - val_accuracy: 0.7183
# Epoch 66/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.8657 - accuracy: 0.7166 - val_loss: 0.8974 - val_accuracy: 0.7068
# Epoch 67/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7982 - accuracy: 0.7209 - val_loss: 0.8661 - val_accuracy: 0.7143
# Epoch 68/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7829 - accuracy: 0.7292 - val_loss: 0.8559 - val_accuracy: 0.7104
# Epoch 69/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.8069 - accuracy: 0.7223 - val_loss: 0.8590 - val_accuracy: 0.7107
# Epoch 70/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7978 - accuracy: 0.7293 - val_loss: 0.8782 - val_accuracy: 0.7151
# Epoch 71/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7783 - accuracy: 0.7267 - val_loss: 0.8639 - val_accuracy: 0.7154
# Epoch 72/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7818 - accuracy: 0.7341 - val_loss: 0.9156 - val_accuracy: 0.7017
# Epoch 73/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7619 - accuracy: 0.7355 - val_loss: 0.8471 - val_accuracy: 0.7176
# Epoch 74/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7728 - accuracy: 0.7357 - val_loss: 0.8895 - val_accuracy: 0.7093
# Epoch 75/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7681 - accuracy: 0.7377 - val_loss: 0.8973 - val_accuracy: 0.7104
# Epoch 76/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7535 - accuracy: 0.7378 - val_loss: 0.8465 - val_accuracy: 0.7187
# Epoch 77/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7856 - accuracy: 0.7330 - val_loss: 0.8400 - val_accuracy: 0.7161
# Epoch 78/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7342 - accuracy: 0.7390 - val_loss: 0.8417 - val_accuracy: 0.7219
# Epoch 79/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7447 - accuracy: 0.7395 - val_loss: 0.8357 - val_accuracy: 0.7223
# Epoch 80/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7347 - accuracy: 0.7419 - val_loss: 0.8178 - val_accuracy: 0.7266
# Epoch 81/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7352 - accuracy: 0.7434 - val_loss: 0.8370 - val_accuracy: 0.7198
# Epoch 82/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7204 - accuracy: 0.7442 - val_loss: 0.8335 - val_accuracy: 0.7226
# Epoch 83/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7270 - accuracy: 0.7413 - val_loss: 0.8212 - val_accuracy: 0.7165
# Epoch 84/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7342 - accuracy: 0.7491 - val_loss: 0.8539 - val_accuracy: 0.7198
# Epoch 85/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7402 - accuracy: 0.7479 - val_loss: 0.8157 - val_accuracy: 0.7266
# Epoch 86/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7270 - accuracy: 0.7488 - val_loss: 0.8554 - val_accuracy: 0.7183
# Epoch 87/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7295 - accuracy: 0.7473 - val_loss: 0.8641 - val_accuracy: 0.7136
# Epoch 88/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7677 - accuracy: 0.7467 - val_loss: 0.8213 - val_accuracy: 0.7223
# Epoch 89/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7165 - accuracy: 0.7531 - val_loss: 0.8299 - val_accuracy: 0.7259
# Epoch 90/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7229 - accuracy: 0.7558 - val_loss: 0.8466 - val_accuracy: 0.7263
# Epoch 91/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6850 - accuracy: 0.7581 - val_loss: 0.8522 - val_accuracy: 0.7161
# Epoch 92/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7184 - accuracy: 0.7528 - val_loss: 0.8261 - val_accuracy: 0.7259
# Epoch 93/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7042 - accuracy: 0.7492 - val_loss: 0.8230 - val_accuracy: 0.7309
# Epoch 94/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6910 - accuracy: 0.7619 - val_loss: 0.8279 - val_accuracy: 0.7302
# Epoch 95/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7038 - accuracy: 0.7557 - val_loss: 0.7919 - val_accuracy: 0.7353
# Epoch 96/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6681 - accuracy: 0.7646 - val_loss: 0.8040 - val_accuracy: 0.7353
# Epoch 97/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6834 - accuracy: 0.7600 - val_loss: 0.8551 - val_accuracy: 0.7259
# Epoch 98/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7112 - accuracy: 0.7573 - val_loss: 0.8030 - val_accuracy: 0.7320
# Epoch 99/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6775 - accuracy: 0.7652 - val_loss: 0.7928 - val_accuracy: 0.7360
# Epoch 100/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6698 - accuracy: 0.7655 - val_loss: 0.7979 - val_accuracy: 0.7302
# Epoch 101/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6628 - accuracy: 0.7655 - val_loss: 0.9233 - val_accuracy: 0.7277
# Epoch 102/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.7153 - accuracy: 0.7610 - val_loss: 0.8105 - val_accuracy: 0.7309
# Epoch 103/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6629 - accuracy: 0.7714 - val_loss: 0.7804 - val_accuracy: 0.7414
# Epoch 104/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6432 - accuracy: 0.7722 - val_loss: 0.7884 - val_accuracy: 0.7371
# Epoch 105/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6693 - accuracy: 0.7692 - val_loss: 0.8064 - val_accuracy: 0.7291
# Epoch 106/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6667 - accuracy: 0.7727 - val_loss: 0.8302 - val_accuracy: 0.7223
# Epoch 107/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6719 - accuracy: 0.7678 - val_loss: 0.7971 - val_accuracy: 0.7360
# Epoch 108/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6536 - accuracy: 0.7729 - val_loss: 0.7877 - val_accuracy: 0.7367
# Epoch 109/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6504 - accuracy: 0.7802 - val_loss: 0.7959 - val_accuracy: 0.7324
# Epoch 110/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.6461 - accuracy: 0.7776 - val_loss: 0.7761 - val_accuracy: 0.7306
# Epoch 111/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.6384 - accuracy: 0.7794 - val_loss: 0.8171 - val_accuracy: 0.7277
# Epoch 112/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.6213 - accuracy: 0.7814 - val_loss: 0.7999 - val_accuracy: 0.7385
# Epoch 113/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.6329 - accuracy: 0.7778 - val_loss: 0.7813 - val_accuracy: 0.7396
# Epoch 114/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6129 - accuracy: 0.7865 - val_loss: 0.7910 - val_accuracy: 0.7385
# Epoch 115/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6359 - accuracy: 0.7761 - val_loss: 0.7925 - val_accuracy: 0.7385
# Epoch 116/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6868 - accuracy: 0.7731 - val_loss: 0.8215 - val_accuracy: 0.7302
# Epoch 117/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.6310 - accuracy: 0.7845 - val_loss: 0.7803 - val_accuracy: 0.7436
# Epoch 118/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6389 - accuracy: 0.7799 - val_loss: 0.7741 - val_accuracy: 0.7414
# Epoch 119/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.6014 - accuracy: 0.7882 - val_loss: 0.7774 - val_accuracy: 0.7414
# Epoch 120/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.6340 - accuracy: 0.7833 - val_loss: 0.8295 - val_accuracy: 0.7400
# Epoch 121/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.6309 - accuracy: 0.7855 - val_loss: 0.7930 - val_accuracy: 0.7443
# Epoch 122/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.6047 - accuracy: 0.7902 - val_loss: 0.7841 - val_accuracy: 0.7465
# Epoch 123/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.6118 - accuracy: 0.7869 - val_loss: 0.7826 - val_accuracy: 0.7411
# Epoch 124/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.6091 - accuracy: 0.7908 - val_loss: 0.8007 - val_accuracy: 0.7407
# Epoch 125/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5985 - accuracy: 0.7939 - val_loss: 0.7926 - val_accuracy: 0.7432
# Epoch 126/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5918 - accuracy: 0.7917 - val_loss: 0.8028 - val_accuracy: 0.7407
# Epoch 127/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.6161 - accuracy: 0.7957 - val_loss: 0.7884 - val_accuracy: 0.7411
# Epoch 128/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.6494 - accuracy: 0.7824 - val_loss: 0.7939 - val_accuracy: 0.7440
# Epoch 129/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5965 - accuracy: 0.7929 - val_loss: 0.7874 - val_accuracy: 0.7403
# Epoch 130/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5882 - accuracy: 0.7946 - val_loss: 0.7867 - val_accuracy: 0.7476
# Epoch 131/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5878 - accuracy: 0.7941 - val_loss: 0.7964 - val_accuracy: 0.7421
# Epoch 132/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5821 - accuracy: 0.7995 - val_loss: 0.7883 - val_accuracy: 0.7497
# Epoch 133/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5862 - accuracy: 0.7947 - val_loss: 0.7777 - val_accuracy: 0.7512
# Epoch 134/1000
# 1385/1385 [==============================] - 4s 3ms/step - loss: 0.6162 - accuracy: 0.7952 - val_loss: 0.8253 - val_accuracy: 0.7476
# Epoch 135/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5687 - accuracy: 0.8055 - val_loss: 0.7736 - val_accuracy: 0.7465
# Epoch 136/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5617 - accuracy: 0.8025 - val_loss: 0.7889 - val_accuracy: 0.7411
# Epoch 137/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5667 - accuracy: 0.8022 - val_loss: 0.7969 - val_accuracy: 0.7497
# Epoch 138/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5730 - accuracy: 0.8036 - val_loss: 0.7642 - val_accuracy: 0.7494
# Epoch 139/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5478 - accuracy: 0.8061 - val_loss: 0.7741 - val_accuracy: 0.7523
# Epoch 140/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5663 - accuracy: 0.7992 - val_loss: 0.7825 - val_accuracy: 0.7501
# Epoch 141/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5740 - accuracy: 0.8010 - val_loss: 0.7872 - val_accuracy: 0.7555
# Epoch 142/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5707 - accuracy: 0.8033 - val_loss: 0.8004 - val_accuracy: 0.7418
# Epoch 143/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5483 - accuracy: 0.8087 - val_loss: 0.7649 - val_accuracy: 0.7523
# Epoch 144/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5337 - accuracy: 0.8112 - val_loss: 0.7840 - val_accuracy: 0.7533
# Epoch 145/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5492 - accuracy: 0.8059 - val_loss: 0.7694 - val_accuracy: 0.7533
# Epoch 146/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5573 - accuracy: 0.8037 - val_loss: 0.7606 - val_accuracy: 0.7505
# Epoch 147/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5445 - accuracy: 0.8097 - val_loss: 0.7629 - val_accuracy: 0.7559
# Epoch 148/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5362 - accuracy: 0.8141 - val_loss: 0.7612 - val_accuracy: 0.7501
# Epoch 149/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5409 - accuracy: 0.8121 - val_loss: 0.7679 - val_accuracy: 0.7544
# Epoch 150/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5307 - accuracy: 0.8157 - val_loss: 0.7597 - val_accuracy: 0.7573
# Epoch 151/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5441 - accuracy: 0.8116 - val_loss: 0.7622 - val_accuracy: 0.7595
# Epoch 152/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5578 - accuracy: 0.8108 - val_loss: 0.8133 - val_accuracy: 0.7501
# Epoch 153/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5389 - accuracy: 0.8149 - val_loss: 0.7544 - val_accuracy: 0.7515
# Epoch 154/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5229 - accuracy: 0.8195 - val_loss: 0.7809 - val_accuracy: 0.7551
# Epoch 155/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5093 - accuracy: 0.8204 - val_loss: 0.7639 - val_accuracy: 0.7584
# Epoch 156/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5304 - accuracy: 0.8198 - val_loss: 0.7630 - val_accuracy: 0.7497
# Epoch 157/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5228 - accuracy: 0.8187 - val_loss: 0.7770 - val_accuracy: 0.7526
# Epoch 158/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5065 - accuracy: 0.8216 - val_loss: 0.7748 - val_accuracy: 0.7533
# Epoch 159/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5064 - accuracy: 0.8243 - val_loss: 0.7973 - val_accuracy: 0.7508
# Epoch 160/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.5007 - accuracy: 0.8279 - val_loss: 0.7635 - val_accuracy: 0.7620
# Epoch 161/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5207 - accuracy: 0.8197 - val_loss: 0.8074 - val_accuracy: 0.7577
# Epoch 162/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4909 - accuracy: 0.8290 - val_loss: 0.7733 - val_accuracy: 0.7609
# Epoch 163/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5021 - accuracy: 0.8238 - val_loss: 0.7674 - val_accuracy: 0.7602
# Epoch 164/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5104 - accuracy: 0.8282 - val_loss: 0.7648 - val_accuracy: 0.7613
# Epoch 165/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4944 - accuracy: 0.8281 - val_loss: 0.7671 - val_accuracy: 0.7616
# Epoch 166/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4823 - accuracy: 0.8290 - val_loss: 0.7498 - val_accuracy: 0.7635
# Epoch 167/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5160 - accuracy: 0.8268 - val_loss: 0.7500 - val_accuracy: 0.7602
# Epoch 168/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4910 - accuracy: 0.8283 - val_loss: 0.7903 - val_accuracy: 0.7624
# Epoch 169/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4946 - accuracy: 0.8303 - val_loss: 0.7623 - val_accuracy: 0.7624
# Epoch 170/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5082 - accuracy: 0.8307 - val_loss: 0.7712 - val_accuracy: 0.7631
# Epoch 171/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4944 - accuracy: 0.8319 - val_loss: 0.7625 - val_accuracy: 0.7620
# Epoch 172/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4859 - accuracy: 0.8302 - val_loss: 0.7962 - val_accuracy: 0.7620
# Epoch 173/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4716 - accuracy: 0.8333 - val_loss: 0.7533 - val_accuracy: 0.7678
# Epoch 174/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4851 - accuracy: 0.8339 - val_loss: 0.8039 - val_accuracy: 0.7696
# Epoch 175/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5103 - accuracy: 0.8306 - val_loss: 0.7884 - val_accuracy: 0.7649
# Epoch 176/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4807 - accuracy: 0.8368 - val_loss: 0.7891 - val_accuracy: 0.7692
# Epoch 177/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4643 - accuracy: 0.8356 - val_loss: 0.7731 - val_accuracy: 0.7663
# Epoch 178/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4723 - accuracy: 0.8362 - val_loss: 0.7739 - val_accuracy: 0.7689
# Epoch 179/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5048 - accuracy: 0.8303 - val_loss: 0.8028 - val_accuracy: 0.7660
# Epoch 180/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4982 - accuracy: 0.8353 - val_loss: 0.8038 - val_accuracy: 0.7653
# Epoch 181/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4792 - accuracy: 0.8347 - val_loss: 0.7748 - val_accuracy: 0.7685
# Epoch 182/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4764 - accuracy: 0.8332 - val_loss: 0.7725 - val_accuracy: 0.7674
# Epoch 183/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4641 - accuracy: 0.8409 - val_loss: 0.7930 - val_accuracy: 0.7674
# Epoch 184/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4703 - accuracy: 0.8366 - val_loss: 0.8851 - val_accuracy: 0.7548
# Epoch 185/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4917 - accuracy: 0.8379 - val_loss: 0.7943 - val_accuracy: 0.7649
# Epoch 186/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.5140 - accuracy: 0.8411 - val_loss: 0.8112 - val_accuracy: 0.7645
# Epoch 187/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4545 - accuracy: 0.8443 - val_loss: 0.7857 - val_accuracy: 0.7649
# Epoch 188/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4668 - accuracy: 0.8413 - val_loss: 0.7533 - val_accuracy: 0.7714
# Epoch 189/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4438 - accuracy: 0.8453 - val_loss: 0.8037 - val_accuracy: 0.7685
# Epoch 190/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4584 - accuracy: 0.8422 - val_loss: 0.8183 - val_accuracy: 0.7746
# Epoch 191/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4790 - accuracy: 0.8371 - val_loss: 0.7706 - val_accuracy: 0.7696
# Epoch 192/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4542 - accuracy: 0.8442 - val_loss: 0.7609 - val_accuracy: 0.7707
# Epoch 193/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4634 - accuracy: 0.8436 - val_loss: 0.7522 - val_accuracy: 0.7718
# Epoch 194/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4443 - accuracy: 0.8490 - val_loss: 0.7927 - val_accuracy: 0.7606
# Epoch 195/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4464 - accuracy: 0.8429 - val_loss: 0.7587 - val_accuracy: 0.7700
# Epoch 196/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4621 - accuracy: 0.8429 - val_loss: 0.7918 - val_accuracy: 0.7703
# Epoch 197/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4307 - accuracy: 0.8528 - val_loss: 0.7928 - val_accuracy: 0.7703
# Epoch 198/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4366 - accuracy: 0.8511 - val_loss: 0.7654 - val_accuracy: 0.7728
# Epoch 199/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4306 - accuracy: 0.8522 - val_loss: 0.7675 - val_accuracy: 0.7783
# Epoch 200/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4406 - accuracy: 0.8488 - val_loss: 0.7846 - val_accuracy: 0.7721
# Epoch 201/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4659 - accuracy: 0.8445 - val_loss: 0.7605 - val_accuracy: 0.7743
# Epoch 202/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4458 - accuracy: 0.8524 - val_loss: 0.8012 - val_accuracy: 0.7783
# Epoch 203/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4337 - accuracy: 0.8513 - val_loss: 0.7737 - val_accuracy: 0.7811
# Epoch 204/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4319 - accuracy: 0.8533 - val_loss: 0.8030 - val_accuracy: 0.7710
# Epoch 205/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4171 - accuracy: 0.8562 - val_loss: 0.7563 - val_accuracy: 0.7826
# Epoch 206/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4246 - accuracy: 0.8554 - val_loss: 0.8011 - val_accuracy: 0.7696
# Epoch 207/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4161 - accuracy: 0.8569 - val_loss: 0.7468 - val_accuracy: 0.7819
# Epoch 208/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4489 - accuracy: 0.8499 - val_loss: 0.7636 - val_accuracy: 0.7804
# Epoch 209/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4302 - accuracy: 0.8528 - val_loss: 0.7615 - val_accuracy: 0.7746
# Epoch 210/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4473 - accuracy: 0.8536 - val_loss: 0.7716 - val_accuracy: 0.7804
# Epoch 211/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4155 - accuracy: 0.8546 - val_loss: 0.7590 - val_accuracy: 0.7768
# Epoch 212/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4235 - accuracy: 0.8598 - val_loss: 0.7633 - val_accuracy: 0.7790
# Epoch 213/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4041 - accuracy: 0.8595 - val_loss: 0.7629 - val_accuracy: 0.7718
# Epoch 214/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4499 - accuracy: 0.8519 - val_loss: 0.7811 - val_accuracy: 0.7746
# Epoch 215/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4124 - accuracy: 0.8562 - val_loss: 0.8029 - val_accuracy: 0.7754
# Epoch 216/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4083 - accuracy: 0.8604 - val_loss: 0.7843 - val_accuracy: 0.7768
# Epoch 217/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4277 - accuracy: 0.8583 - val_loss: 0.8848 - val_accuracy: 0.7671
# Epoch 218/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.4162 - accuracy: 0.8563 - val_loss: 0.7772 - val_accuracy: 0.7775
# Epoch 219/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4105 - accuracy: 0.8596 - val_loss: 0.7900 - val_accuracy: 0.7797
# Epoch 220/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4339 - accuracy: 0.8602 - val_loss: 0.7443 - val_accuracy: 0.7804
# Epoch 221/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.3963 - accuracy: 0.8639 - val_loss: 0.7671 - val_accuracy: 0.7833
# Epoch 222/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4124 - accuracy: 0.8634 - val_loss: 0.7891 - val_accuracy: 0.7772
# Epoch 223/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4094 - accuracy: 0.8635 - val_loss: 0.7815 - val_accuracy: 0.7743
# Epoch 224/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3881 - accuracy: 0.8674 - val_loss: 0.7481 - val_accuracy: 0.7826
# Epoch 225/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4256 - accuracy: 0.8630 - val_loss: 0.7699 - val_accuracy: 0.7779
# Epoch 226/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.4014 - accuracy: 0.8641 - val_loss: 0.7655 - val_accuracy: 0.7855
# Epoch 227/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.4028 - accuracy: 0.8655 - val_loss: 0.8237 - val_accuracy: 0.7822
# Epoch 228/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.3931 - accuracy: 0.8664 - val_loss: 0.7974 - val_accuracy: 0.7804
# Epoch 229/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.3771 - accuracy: 0.8649 - val_loss: 0.7920 - val_accuracy: 0.7681
# Epoch 230/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.3996 - accuracy: 0.8642 - val_loss: 0.7846 - val_accuracy: 0.7815
# Epoch 231/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.3881 - accuracy: 0.8646 - val_loss: 0.7555 - val_accuracy: 0.7858
# Epoch 232/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.3935 - accuracy: 0.8679 - val_loss: 0.7712 - val_accuracy: 0.7844
# Epoch 233/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3804 - accuracy: 0.8711 - val_loss: 0.7588 - val_accuracy: 0.7793
# Epoch 234/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4178 - accuracy: 0.8673 - val_loss: 0.8301 - val_accuracy: 0.7743
# Epoch 235/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3747 - accuracy: 0.8723 - val_loss: 0.7836 - val_accuracy: 0.7826
# Epoch 236/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3906 - accuracy: 0.8711 - val_loss: 0.7739 - val_accuracy: 0.7786
# Epoch 237/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3864 - accuracy: 0.8665 - val_loss: 0.7782 - val_accuracy: 0.7880
# Epoch 238/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.4142 - accuracy: 0.8633 - val_loss: 0.7884 - val_accuracy: 0.7790
# Epoch 239/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3763 - accuracy: 0.8731 - val_loss: 0.7655 - val_accuracy: 0.7801
# Epoch 240/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3761 - accuracy: 0.8715 - val_loss: 0.7828 - val_accuracy: 0.7840
# Epoch 241/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3692 - accuracy: 0.8773 - val_loss: 0.7746 - val_accuracy: 0.7833
# Epoch 242/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3876 - accuracy: 0.8737 - val_loss: 0.8298 - val_accuracy: 0.7869
# Epoch 243/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3652 - accuracy: 0.8788 - val_loss: 0.7735 - val_accuracy: 0.7855
# Epoch 244/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3722 - accuracy: 0.8722 - val_loss: 0.8111 - val_accuracy: 0.7840
# Epoch 245/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3874 - accuracy: 0.8688 - val_loss: 0.7799 - val_accuracy: 0.7855
# Epoch 246/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3839 - accuracy: 0.8707 - val_loss: 0.7838 - val_accuracy: 0.7855
# Epoch 247/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3766 - accuracy: 0.8748 - val_loss: 0.7782 - val_accuracy: 0.7826
# Epoch 248/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3614 - accuracy: 0.8728 - val_loss: 0.7713 - val_accuracy: 0.7876
# Epoch 249/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3749 - accuracy: 0.8709 - val_loss: 0.7796 - val_accuracy: 0.7775
# Epoch 250/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3594 - accuracy: 0.8791 - val_loss: 0.7809 - val_accuracy: 0.7840
# Epoch 251/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3874 - accuracy: 0.8753 - val_loss: 0.7656 - val_accuracy: 0.7826
# Epoch 252/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3559 - accuracy: 0.8758 - val_loss: 0.7722 - val_accuracy: 0.7819
# Epoch 253/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.3998 - accuracy: 0.8731 - val_loss: 0.7914 - val_accuracy: 0.7736
# Epoch 254/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3952 - accuracy: 0.8719 - val_loss: 0.8085 - val_accuracy: 0.7848
# Epoch 255/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3573 - accuracy: 0.8808 - val_loss: 0.7918 - val_accuracy: 0.7833
# Epoch 256/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3574 - accuracy: 0.8819 - val_loss: 0.8785 - val_accuracy: 0.7848
# Epoch 257/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3764 - accuracy: 0.8734 - val_loss: 0.7862 - val_accuracy: 0.7815
# Epoch 258/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3860 - accuracy: 0.8786 - val_loss: 0.7903 - val_accuracy: 0.7840
# Epoch 259/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.3525 - accuracy: 0.8805 - val_loss: 0.7700 - val_accuracy: 0.7869
# Epoch 260/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.3431 - accuracy: 0.8804 - val_loss: 0.7840 - val_accuracy: 0.7833
# Epoch 261/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3497 - accuracy: 0.8849 - val_loss: 0.7775 - val_accuracy: 0.7880
# Epoch 262/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3731 - accuracy: 0.8764 - val_loss: 0.8170 - val_accuracy: 0.7808
# Epoch 263/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3474 - accuracy: 0.8822 - val_loss: 0.8314 - val_accuracy: 0.7840
# Epoch 264/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3495 - accuracy: 0.8813 - val_loss: 0.7751 - val_accuracy: 0.7880
# Epoch 265/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3495 - accuracy: 0.8798 - val_loss: 0.7672 - val_accuracy: 0.7902
# Epoch 266/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3546 - accuracy: 0.8814 - val_loss: 0.8444 - val_accuracy: 0.7811
# Epoch 267/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3327 - accuracy: 0.8871 - val_loss: 0.7781 - val_accuracy: 0.7873
# Epoch 268/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3360 - accuracy: 0.8868 - val_loss: 0.7779 - val_accuracy: 0.7887
# Epoch 269/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3524 - accuracy: 0.8843 - val_loss: 0.7665 - val_accuracy: 0.7862
# Epoch 270/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3706 - accuracy: 0.8812 - val_loss: 0.7815 - val_accuracy: 0.7873
# Epoch 271/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3451 - accuracy: 0.8871 - val_loss: 0.8239 - val_accuracy: 0.7826
# Epoch 272/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3571 - accuracy: 0.8855 - val_loss: 0.8060 - val_accuracy: 0.7757
# Epoch 273/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3388 - accuracy: 0.8850 - val_loss: 0.7965 - val_accuracy: 0.7840
# Epoch 274/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3320 - accuracy: 0.8895 - val_loss: 0.8556 - val_accuracy: 0.7808
# Epoch 275/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3755 - accuracy: 0.8823 - val_loss: 0.8040 - val_accuracy: 0.7898
# Epoch 276/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3232 - accuracy: 0.8888 - val_loss: 0.7936 - val_accuracy: 0.7869
# Epoch 277/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3473 - accuracy: 0.8837 - val_loss: 0.7781 - val_accuracy: 0.7941
# Epoch 278/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3202 - accuracy: 0.8872 - val_loss: 0.7749 - val_accuracy: 0.7931
# Epoch 279/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3305 - accuracy: 0.8848 - val_loss: 0.8136 - val_accuracy: 0.7797
# Epoch 280/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.3372 - accuracy: 0.8858 - val_loss: 0.7763 - val_accuracy: 0.7931
# Epoch 281/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3381 - accuracy: 0.8895 - val_loss: 0.7751 - val_accuracy: 0.7927
# Epoch 282/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3501 - accuracy: 0.8870 - val_loss: 0.7556 - val_accuracy: 0.7884
# Epoch 283/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3639 - accuracy: 0.8873 - val_loss: 0.8160 - val_accuracy: 0.7833
# Epoch 284/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3369 - accuracy: 0.8902 - val_loss: 0.8645 - val_accuracy: 0.7833
# Epoch 285/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3388 - accuracy: 0.8900 - val_loss: 0.7660 - val_accuracy: 0.7916
# Epoch 286/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3369 - accuracy: 0.8843 - val_loss: 0.7275 - val_accuracy: 0.7895
# Epoch 287/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3209 - accuracy: 0.8934 - val_loss: 0.7861 - val_accuracy: 0.7822
# Epoch 288/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3297 - accuracy: 0.8933 - val_loss: 0.8266 - val_accuracy: 0.7833
# Epoch 289/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3205 - accuracy: 0.8891 - val_loss: 0.7369 - val_accuracy: 0.7876
# Epoch 290/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3146 - accuracy: 0.8968 - val_loss: 0.7581 - val_accuracy: 0.7909
# Epoch 291/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3764 - accuracy: 0.8851 - val_loss: 0.7845 - val_accuracy: 0.7830
# Epoch 292/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3230 - accuracy: 0.8921 - val_loss: 0.7715 - val_accuracy: 0.7898
# Epoch 293/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3157 - accuracy: 0.8946 - val_loss: 0.7682 - val_accuracy: 0.7858
# Epoch 294/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.3320 - accuracy: 0.8915 - val_loss: 0.7923 - val_accuracy: 0.7775
# Epoch 295/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3300 - accuracy: 0.8912 - val_loss: 0.8083 - val_accuracy: 0.7876
# Epoch 296/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.3305 - accuracy: 0.8899 - val_loss: 0.7870 - val_accuracy: 0.7876
# Epoch 297/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3033 - accuracy: 0.8995 - val_loss: 0.7961 - val_accuracy: 0.7967
# Epoch 298/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.3697 - accuracy: 0.8936 - val_loss: 0.7863 - val_accuracy: 0.7909
# Epoch 299/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3306 - accuracy: 0.8923 - val_loss: 0.7729 - val_accuracy: 0.7916
# Epoch 300/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3078 - accuracy: 0.8975 - val_loss: 0.7629 - val_accuracy: 0.7916
# Epoch 301/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3227 - accuracy: 0.8952 - val_loss: 0.8006 - val_accuracy: 0.7891
# Epoch 302/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3123 - accuracy: 0.8971 - val_loss: 0.8092 - val_accuracy: 0.7884
# Epoch 303/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3181 - accuracy: 0.8950 - val_loss: 0.7537 - val_accuracy: 0.7895
# Epoch 304/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.3010 - accuracy: 0.8978 - val_loss: 0.7703 - val_accuracy: 0.7761
# Epoch 305/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3135 - accuracy: 0.8985 - val_loss: 0.7875 - val_accuracy: 0.7895
# Epoch 306/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3811 - accuracy: 0.8914 - val_loss: 0.7906 - val_accuracy: 0.7981
# Epoch 307/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.3020 - accuracy: 0.8970 - val_loss: 0.7946 - val_accuracy: 0.7956
# Epoch 308/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.2842 - accuracy: 0.9022 - val_loss: 0.8180 - val_accuracy: 0.7909
# Epoch 309/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3029 - accuracy: 0.8969 - val_loss: 0.8010 - val_accuracy: 0.7830
# Epoch 310/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3167 - accuracy: 0.8961 - val_loss: 0.7977 - val_accuracy: 0.7920
# Epoch 311/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3157 - accuracy: 0.9013 - val_loss: 0.7962 - val_accuracy: 0.7895
# Epoch 312/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3137 - accuracy: 0.9014 - val_loss: 0.8383 - val_accuracy: 0.7858
# Epoch 313/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.2950 - accuracy: 0.9014 - val_loss: 0.8074 - val_accuracy: 0.7949
# Epoch 314/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3232 - accuracy: 0.8951 - val_loss: 0.7818 - val_accuracy: 0.7909
# Epoch 315/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.2866 - accuracy: 0.9027 - val_loss: 0.7873 - val_accuracy: 0.7931
# Epoch 316/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3285 - accuracy: 0.8966 - val_loss: 0.7607 - val_accuracy: 0.7941
# Epoch 317/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3135 - accuracy: 0.8984 - val_loss: 0.8206 - val_accuracy: 0.7891
# Epoch 318/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.2905 - accuracy: 0.9035 - val_loss: 0.7520 - val_accuracy: 0.7988
# Epoch 319/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3226 - accuracy: 0.8949 - val_loss: 0.8115 - val_accuracy: 0.7905
# Epoch 320/1000
# 1385/1385 [==============================] - 6s 4ms/step - loss: 0.2887 - accuracy: 0.9024 - val_loss: 0.7841 - val_accuracy: 0.7974
# Epoch 321/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.2952 - accuracy: 0.9062 - val_loss: 0.7810 - val_accuracy: 0.7931
# Epoch 322/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.2993 - accuracy: 0.9027 - val_loss: 0.7725 - val_accuracy: 0.7891
# Epoch 323/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.2993 - accuracy: 0.8961 - val_loss: 0.8766 - val_accuracy: 0.7887
# Epoch 324/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.2930 - accuracy: 0.9026 - val_loss: 0.8920 - val_accuracy: 0.7873
# Epoch 325/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.3115 - accuracy: 0.8989 - val_loss: 0.8789 - val_accuracy: 0.7876
# ...
# Epoch 893/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1487 - accuracy: 0.9652 - val_loss: 0.9635 - val_accuracy: 0.8155
# Epoch 894/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1218 - accuracy: 0.9660 - val_loss: 0.9679 - val_accuracy: 0.8118
# Epoch 895/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1107 - accuracy: 0.9658 - val_loss: 1.1953 - val_accuracy: 0.8140
# Epoch 896/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1738 - accuracy: 0.9600 - val_loss: 1.0103 - val_accuracy: 0.8144
# Epoch 897/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1118 - accuracy: 0.9671 - val_loss: 1.0790 - val_accuracy: 0.8126
# Epoch 898/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1747 - accuracy: 0.9630 - val_loss: 1.0339 - val_accuracy: 0.8140
# Epoch 899/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1171 - accuracy: 0.9632 - val_loss: 0.9656 - val_accuracy: 0.8173
# Epoch 900/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1209 - accuracy: 0.9645 - val_loss: 0.9506 - val_accuracy: 0.8126
# Epoch 901/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1107 - accuracy: 0.9675 - val_loss: 0.9806 - val_accuracy: 0.8173
# Epoch 902/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1690 - accuracy: 0.9632 - val_loss: 1.0831 - val_accuracy: 0.8147
# Epoch 903/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1134 - accuracy: 0.9664 - val_loss: 1.0816 - val_accuracy: 0.8129
# Epoch 904/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1265 - accuracy: 0.9622 - val_loss: 1.0524 - val_accuracy: 0.8090
# Epoch 905/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1235 - accuracy: 0.9716 - val_loss: 0.9636 - val_accuracy: 0.8169
# Epoch 906/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1705 - accuracy: 0.9617 - val_loss: 0.9462 - val_accuracy: 0.8061
# Epoch 907/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1767 - accuracy: 0.9593 - val_loss: 0.9901 - val_accuracy: 0.8068
# Epoch 908/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1262 - accuracy: 0.9643 - val_loss: 0.9928 - val_accuracy: 0.8090
# Epoch 909/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1218 - accuracy: 0.9658 - val_loss: 1.1092 - val_accuracy: 0.8075
# Epoch 910/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1519 - accuracy: 0.9644 - val_loss: 1.0743 - val_accuracy: 0.8039
# Epoch 911/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1725 - accuracy: 0.9633 - val_loss: 1.0491 - val_accuracy: 0.8082
# Epoch 912/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1257 - accuracy: 0.9616 - val_loss: 0.9665 - val_accuracy: 0.8093
# Epoch 913/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1393 - accuracy: 0.9638 - val_loss: 0.9850 - val_accuracy: 0.8155
# Epoch 914/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1313 - accuracy: 0.9666 - val_loss: 0.8991 - val_accuracy: 0.8158
# Epoch 915/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1159 - accuracy: 0.9683 - val_loss: 0.9518 - val_accuracy: 0.8169
# Epoch 916/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1053 - accuracy: 0.9686 - val_loss: 0.9562 - val_accuracy: 0.8155
# Epoch 917/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1443 - accuracy: 0.9682 - val_loss: 0.9910 - val_accuracy: 0.8050
# Epoch 918/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1421 - accuracy: 0.9600 - val_loss: 0.8937 - val_accuracy: 0.8097
# Epoch 919/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1329 - accuracy: 0.9666 - val_loss: 1.0304 - val_accuracy: 0.8093
# Epoch 920/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1077 - accuracy: 0.9652 - val_loss: 0.8767 - val_accuracy: 0.8162
# Epoch 921/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1090 - accuracy: 0.9674 - val_loss: 0.9512 - val_accuracy: 0.8118
# Epoch 922/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1170 - accuracy: 0.9666 - val_loss: 0.9544 - val_accuracy: 0.8137
# Epoch 923/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1238 - accuracy: 0.9685 - val_loss: 0.9302 - val_accuracy: 0.8122
# Epoch 924/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1402 - accuracy: 0.9677 - val_loss: 0.9283 - val_accuracy: 0.8169
# Epoch 925/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1469 - accuracy: 0.9629 - val_loss: 1.0247 - val_accuracy: 0.8183
# Epoch 926/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1231 - accuracy: 0.9679 - val_loss: 1.0859 - val_accuracy: 0.8122
# Epoch 927/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1441 - accuracy: 0.9657 - val_loss: 0.9430 - val_accuracy: 0.8140
# Epoch 928/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1185 - accuracy: 0.9648 - val_loss: 0.9064 - val_accuracy: 0.8133
# Epoch 929/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1228 - accuracy: 0.9665 - val_loss: 0.9685 - val_accuracy: 0.8090
# Epoch 930/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1287 - accuracy: 0.9630 - val_loss: 1.1315 - val_accuracy: 0.8072
# Epoch 931/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1306 - accuracy: 0.9617 - val_loss: 0.9785 - val_accuracy: 0.8180
# Epoch 932/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1162 - accuracy: 0.9680 - val_loss: 0.9643 - val_accuracy: 0.8097
# Epoch 933/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1210 - accuracy: 0.9676 - val_loss: 0.9379 - val_accuracy: 0.8133
# Epoch 934/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1247 - accuracy: 0.9652 - val_loss: 1.1800 - val_accuracy: 0.8072
# Epoch 935/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1551 - accuracy: 0.9613 - val_loss: 0.9894 - val_accuracy: 0.8082
# Epoch 936/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1346 - accuracy: 0.9650 - val_loss: 0.9380 - val_accuracy: 0.8097
# Epoch 937/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.0956 - accuracy: 0.9674 - val_loss: 1.0064 - val_accuracy: 0.8118
# Epoch 938/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1156 - accuracy: 0.9642 - val_loss: 1.0575 - val_accuracy: 0.8187
# Epoch 939/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1437 - accuracy: 0.9637 - val_loss: 1.0402 - val_accuracy: 0.8122
# Epoch 940/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1173 - accuracy: 0.9687 - val_loss: 0.9402 - val_accuracy: 0.8108
# Epoch 941/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1146 - accuracy: 0.9678 - val_loss: 0.9513 - val_accuracy: 0.8093
# Epoch 942/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1350 - accuracy: 0.9642 - val_loss: 0.9979 - val_accuracy: 0.8075
# Epoch 943/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1245 - accuracy: 0.9658 - val_loss: 0.9637 - val_accuracy: 0.8115
# Epoch 944/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1171 - accuracy: 0.9658 - val_loss: 0.9797 - val_accuracy: 0.8115
# Epoch 945/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1127 - accuracy: 0.9696 - val_loss: 0.9784 - val_accuracy: 0.8093
# Epoch 946/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1096 - accuracy: 0.9689 - val_loss: 0.9337 - val_accuracy: 0.8162
# Epoch 947/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1061 - accuracy: 0.9688 - val_loss: 0.9765 - val_accuracy: 0.8108
# Epoch 948/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1084 - accuracy: 0.9661 - val_loss: 1.0197 - val_accuracy: 0.8075
# Epoch 949/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1149 - accuracy: 0.9665 - val_loss: 1.0393 - val_accuracy: 0.8137
# Epoch 950/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1296 - accuracy: 0.9647 - val_loss: 1.0438 - val_accuracy: 0.8007
# Epoch 951/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1391 - accuracy: 0.9660 - val_loss: 0.9793 - val_accuracy: 0.8100
# Epoch 952/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.0998 - accuracy: 0.9686 - val_loss: 1.0014 - val_accuracy: 0.8137
# Epoch 953/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1055 - accuracy: 0.9662 - val_loss: 1.2023 - val_accuracy: 0.8097
# Epoch 954/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1213 - accuracy: 0.9633 - val_loss: 1.0108 - val_accuracy: 0.8115
# Epoch 955/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.0977 - accuracy: 0.9741 - val_loss: 1.0463 - val_accuracy: 0.8122
# Epoch 956/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1350 - accuracy: 0.9704 - val_loss: 0.9998 - val_accuracy: 0.8093
# Epoch 957/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1447 - accuracy: 0.9651 - val_loss: 0.9655 - val_accuracy: 0.8079
# Epoch 958/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1074 - accuracy: 0.9663 - val_loss: 1.0233 - val_accuracy: 0.8155
# Epoch 959/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1291 - accuracy: 0.9684 - val_loss: 0.9687 - val_accuracy: 0.8162
# Epoch 960/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1756 - accuracy: 0.9645 - val_loss: 1.0651 - val_accuracy: 0.8140
# Epoch 961/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1196 - accuracy: 0.9641 - val_loss: 1.0543 - val_accuracy: 0.8205
# Epoch 962/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1531 - accuracy: 0.9666 - val_loss: 1.0318 - val_accuracy: 0.8133
# Epoch 963/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1380 - accuracy: 0.9656 - val_loss: 1.0255 - val_accuracy: 0.8187
# Epoch 964/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1253 - accuracy: 0.9650 - val_loss: 1.0222 - val_accuracy: 0.8122
# Epoch 965/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1149 - accuracy: 0.9679 - val_loss: 1.0432 - val_accuracy: 0.8155
# Epoch 966/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.0985 - accuracy: 0.9673 - val_loss: 0.9269 - val_accuracy: 0.8245
# Epoch 967/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1383 - accuracy: 0.9669 - val_loss: 0.9551 - val_accuracy: 0.8162
# Epoch 968/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.0981 - accuracy: 0.9697 - val_loss: 0.9258 - val_accuracy: 0.8198
# Epoch 969/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1147 - accuracy: 0.9684 - val_loss: 0.9861 - val_accuracy: 0.8126
# Epoch 970/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1354 - accuracy: 0.9666 - val_loss: 1.1641 - val_accuracy: 0.8122
# Epoch 971/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1286 - accuracy: 0.9652 - val_loss: 1.0133 - val_accuracy: 0.8183
# Epoch 972/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1225 - accuracy: 0.9688 - val_loss: 1.0010 - val_accuracy: 0.8180
# Epoch 973/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1347 - accuracy: 0.9625 - val_loss: 1.0386 - val_accuracy: 0.8115
# Epoch 974/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1096 - accuracy: 0.9664 - val_loss: 1.0186 - val_accuracy: 0.8165
# Epoch 975/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1069 - accuracy: 0.9716 - val_loss: 1.0648 - val_accuracy: 0.8183
# Epoch 976/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1046 - accuracy: 0.9674 - val_loss: 0.9270 - val_accuracy: 0.8165
# Epoch 977/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1655 - accuracy: 0.9685 - val_loss: 0.9753 - val_accuracy: 0.8137
# Epoch 978/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1208 - accuracy: 0.9649 - val_loss: 0.9853 - val_accuracy: 0.8115
# Epoch 979/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1423 - accuracy: 0.9684 - val_loss: 0.9813 - val_accuracy: 0.8140
# Epoch 980/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.0964 - accuracy: 0.9684 - val_loss: 0.9521 - val_accuracy: 0.8158
# Epoch 981/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1052 - accuracy: 0.9677 - val_loss: 1.0009 - val_accuracy: 0.8151
# Epoch 982/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.0909 - accuracy: 0.9728 - val_loss: 0.9983 - val_accuracy: 0.8165
# Epoch 983/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1056 - accuracy: 0.9678 - val_loss: 1.0353 - val_accuracy: 0.8129
# Epoch 984/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1050 - accuracy: 0.9711 - val_loss: 0.9713 - val_accuracy: 0.8187
# Epoch 985/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1749 - accuracy: 0.9621 - val_loss: 1.1086 - val_accuracy: 0.8144
# Epoch 986/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1430 - accuracy: 0.9669 - val_loss: 1.0804 - val_accuracy: 0.8162
# Epoch 987/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1315 - accuracy: 0.9653 - val_loss: 1.0388 - val_accuracy: 0.8202
# Epoch 988/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1094 - accuracy: 0.9671 - val_loss: 1.0276 - val_accuracy: 0.8140
# Epoch 989/1000
# 1385/1385 [==============================] - 5s 3ms/step - loss: 0.1296 - accuracy: 0.9666 - val_loss: 0.9941 - val_accuracy: 0.8137
# Epoch 990/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1054 - accuracy: 0.9663 - val_loss: 1.0528 - val_accuracy: 0.8194
# Epoch 991/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.0956 - accuracy: 0.9736 - val_loss: 0.9734 - val_accuracy: 0.8216
# Epoch 992/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1080 - accuracy: 0.9698 - val_loss: 1.0160 - val_accuracy: 0.8173
# Epoch 993/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1015 - accuracy: 0.9719 - val_loss: 0.9902 - val_accuracy: 0.8093
# Epoch 994/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1130 - accuracy: 0.9698 - val_loss: 0.9045 - val_accuracy: 0.8147
# Epoch 995/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1365 - accuracy: 0.9655 - val_loss: 1.0203 - val_accuracy: 0.8082
# Epoch 996/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1401 - accuracy: 0.9665 - val_loss: 0.9905 - val_accuracy: 0.8169
# Epoch 997/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.0870 - accuracy: 0.9738 - val_loss: 0.9542 - val_accuracy: 0.8144
# Epoch 998/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1156 - accuracy: 0.9668 - val_loss: 0.9811 - val_accuracy: 0.8086
# Epoch 999/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1076 - accuracy: 0.9704 - val_loss: 0.9650 - val_accuracy: 0.8183
# Epoch 1000/1000
# 1385/1385 [==============================] - 5s 4ms/step - loss: 0.1124 - accuracy: 0.9688 - val_loss: 1.0367 - val_accuracy: 0.8118

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

#plt.figure(figsize=(18,3))
#plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
#plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
#plt.legend()
#plt.grid(alpha=.3)
#plt.show()

# %%
model.save("Models/Model1")
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %%
predictions = model.predict(x_test)
predictions.shape
# Out:
# 4/4 [==============================] - 0s 3ms/step
# (122, 12)

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.7541
# Precision: 0.7425
# Recall: 0.6128
# F1: 0.6514
