# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd /gdrive/My Drive/ANN2
# Out:
# /gdrive/My Drive/ANN2

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import warnings
import logging

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.9.2

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
import warnings
import logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)
tf.get_logger().setLevel('INFO')
tf.autograph.set_verbosity(0)

tf.get_logger().setLevel(logging.ERROR)
tf.get_logger().setLevel('ERROR')
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
label_mapping =  {'Wish':0,        #0
          'Another':1,      #1
          'Comfortably':2,  #2
          'Money':3,        #3
          'Breathe':4,      #4
          'Time':5,         #5
          'Brain':6,        #6
          'Echoes':7,       #7
          'Wearing':8,      #8
          'Sorrow':9,       #9
          'Hey':10,          #10
          'Shine':11}      #11

# %%
x_train = np.load("Dataset/x_train.npy")
y_train = np.load("Dataset/y_train.npy")
#dataset.shape, labels.shape

# %%
#x_train, y_train = shuffle(dataset, labels, random_state=0)
#indices = np.arange(dataset.shape[0])
#np.random.shuffle(indices)

#x_train = dataset[indices]
#y_train = labels[indices]

#x_train.shape, y_train.shape

# %%
y_train = tfk.utils.to_categorical(y_train)
x_train.shape, y_train.shape
# Out:
# ((2429, 36, 6), (2429, 12))

# %%
#x_train = np.asarray([dataset[i, :, :] for i in range(int(dataset.shape[0] * 0.7))])
#x_val = np.asarray([dataset[i, :, :] for i in range(int(dataset.shape[0] * 0.7), int(len(dataset) * 0.9))])
#x_test = np.asarray([dataset[i, :, :] for i in range(int(dataset.shape[0] * 0.9), len(dataset))])
#x_train.shape, x_val.shape, x_test.shape

# %%
#y_train = np.asarray([labels[i, :] for i in range(int(labels.shape[0] * 0.7))])
#y_val = np.asarray([labels[i, :] for i in range(int(labels.shape[0] * 0.7), int(len(labels) * 0.9))])
#y_test = np.asarray([labels[i, :] for i in range(int(labels.shape[0] * 0.9), len(labels))])
#y_train.shape, y_val.shape, y_test.shape

# %%
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.05, random_state=seed, shuffle=True, stratify=y_train)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=seed, shuffle=True, stratify=y_train)
x_train.shape, x_val.shape, x_test.shape
# Out:
# ((1845, 36, 6), (462, 36, 6), (122, 36, 6))

# %%
#for i in range(0, 6):
#  data = x_train[:, :, i]
#  min = data.min(axis=(1), keepdims=True)
#  max = data.max(axis=(1), keepdims=True)
#  x_train[:, :, i] = (x_train[:, :, i] - min)/(max - min)

# %%
#scaler = StandardScaler()
#x_train = scaler.fit_transform(x_train.reshape(-1, x_train.shape[-1])).reshape(x_train.shape)
#x_train.shape

# %%
#scaler = MinMaxScaler()
#x_train = scaler.fit_transform(x_train.reshape(-1, x_train.shape[-1])).reshape(x_train.shape)
#x_train.shape

# %%
#x_train_min = x_train.min(axis=(2), keepdims=True)
#x_train_max = x_train.max(axis=(2), keepdims=True)
#(v - v_min)/(v_max - v_min)

#x_train = (x_train - x_train_min)/(x_train_max - x_train_min)
#x_val = (x_val - x_train_min)/(x_train_max - x_train_min)
#x_test = (x_test - x_train_min)/(x_train_max - x_train_min)
#x_train
#x_train_min, x_train_max

# %%
input_shape = x_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 8
epochs = 400

# %%
def build_BiLSTM_classifier(input_shape):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    bilstm = tfkl.Bidirectional(tfkl.LSTM(256, return_sequences=True, kernel_regularizer=tf.keras.regularizers.L1(1e-2), dropout=0.3))(input_layer)
    #bilstm = tfkl.Bidirectional(tfkl.LSTM(64, return_sequences=True, return_state=True, kernel_regularizer=tf.keras.regularizers.L1(1e-2), dropout=0.3))(bilstm)
    bilstm = tfkl.Bidirectional(tfkl.LSTM(256, kernel_regularizer=tf.keras.regularizers.L1(1e-2), dropout=0.3))(bilstm)
    #bilstm = tfkl.Bidirectional(tfkl.LSTM(64, kernel_regularizer=tf.keras.regularizers.L1(2e-4), dropout=0.3))(bilstm)
    #dropout = tfkl.Dropout(.3, seed=seed)(bilstm)

    # Classifier
    classifier_layer = tfkl.Dense(units=512, name='Classifier', kernel_initializer=tfk.initializers.HeUniform(seed), activation='relu')(bilstm)
    dropout = tfkl.Dropout(0.2, seed=seed)(classifier_layer)
    output_layer = tfkl.Dense(units=12, activation='softmax', kernel_initializer=tfk.initializers.GlorotUniform(seed), name='output_layer')(dropout)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(learning_rate=0.0001), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_BiLSTM_classifier(input_shape)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 36, 6)]           0
#
#  bidirectional_7 (Bidirectio  (None, 36, 512)          538624
#  nal)
#
#  bidirectional_8 (Bidirectio  (None, 512)              1574912
#  nal)
#
#  Classifier (Dense)          (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  output_layer (Dense)        (None, 12)                6156
#
# =================================================================
# Total params: 2,382,348
# Trainable params: 2,382,348
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (x_val, y_val),
    #validation_split=.2,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True)
        #tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/400
# 231/231 [==============================] - 10s 22ms/step - loss: 166.6023 - accuracy: 0.3767 - val_loss: 89.9949 - val_accuracy: 0.4589
# Epoch 2/400
# 231/231 [==============================] - 4s 16ms/step - loss: 49.8794 - accuracy: 0.4743 - val_loss: 22.1486 - val_accuracy: 0.5087
# Epoch 3/400
# 231/231 [==============================] - 4s 16ms/step - loss: 11.2359 - accuracy: 0.5003 - val_loss: 4.6599 - val_accuracy: 0.5130
# Epoch 4/400
# 231/231 [==============================] - 4s 16ms/step - loss: 2.7191 - accuracy: 0.5290 - val_loss: 1.7326 - val_accuracy: 0.5519
# Epoch 5/400
# 231/231 [==============================] - 4s 16ms/step - loss: 1.4863 - accuracy: 0.5458 - val_loss: 1.4065 - val_accuracy: 0.5866
# Epoch 6/400
# 231/231 [==============================] - 4s 16ms/step - loss: 1.2990 - accuracy: 0.6005 - val_loss: 1.3626 - val_accuracy: 0.5779
# Epoch 7/400
# 231/231 [==============================] - 4s 16ms/step - loss: 1.2506 - accuracy: 0.6038 - val_loss: 1.3528 - val_accuracy: 0.5844
# Epoch 8/400
# 231/231 [==============================] - 4s 16ms/step - loss: 1.2000 - accuracy: 0.6179 - val_loss: 1.3761 - val_accuracy: 0.5476
# Epoch 9/400
# 231/231 [==============================] - 4s 16ms/step - loss: 1.1251 - accuracy: 0.6596 - val_loss: 1.2865 - val_accuracy: 0.6169
# Epoch 10/400
# 231/231 [==============================] - 4s 16ms/step - loss: 1.1117 - accuracy: 0.6688 - val_loss: 1.2855 - val_accuracy: 0.6320
# Epoch 11/400
# 231/231 [==============================] - 4s 16ms/step - loss: 1.0727 - accuracy: 0.6710 - val_loss: 1.3083 - val_accuracy: 0.6169
# Epoch 12/400
# 231/231 [==============================] - 4s 16ms/step - loss: 1.0318 - accuracy: 0.6883 - val_loss: 1.3077 - val_accuracy: 0.6039
# Epoch 13/400
# 231/231 [==============================] - 4s 16ms/step - loss: 1.0109 - accuracy: 0.6889 - val_loss: 1.3151 - val_accuracy: 0.6169
# Epoch 14/400
# 231/231 [==============================] - 4s 16ms/step - loss: 0.9767 - accuracy: 0.7127 - val_loss: 1.3176 - val_accuracy: 0.6147
# Epoch 15/400
# 231/231 [==============================] - 4s 16ms/step - loss: 0.9356 - accuracy: 0.7366 - val_loss: 1.3553 - val_accuracy: 0.5887
# Epoch 16/400
# 231/231 [==============================] - 4s 16ms/step - loss: 0.9294 - accuracy: 0.7328 - val_loss: 1.3251 - val_accuracy: 0.5909
# Epoch 17/400
# 231/231 [==============================] - 4s 16ms/step - loss: 0.8693 - accuracy: 0.7556 - val_loss: 1.3324 - val_accuracy: 0.6061
# Epoch 18/400
# 231/231 [==============================] - 4s 16ms/step - loss: 0.8913 - accuracy: 0.7431 - val_loss: 1.3541 - val_accuracy: 0.5801
# Epoch 19/400
# 231/231 [==============================] - 4s 16ms/step - loss: 0.8433 - accuracy: 0.7724 - val_loss: 1.3682 - val_accuracy: 0.5974
# Epoch 20/400
# 231/231 [==============================] - 4s 16ms/step - loss: 0.8254 - accuracy: 0.7740 - val_loss: 1.3918 - val_accuracy: 0.5996

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

#plt.figure(figsize=(18,3))
#plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
#plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
#plt.legend()
#plt.grid(alpha=.3)
#plt.show()

# %%
model.save("Models/Model3")
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn, lstm_cell_23_layer_call_and_return_conditional_losses, lstm_cell_25_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.

# %%
predictions = model.predict(x_test)
predictions.shape
# Out:
# 4/4 [==============================] - 1s 7ms/step
# (122, 12)

# %%
#Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.623
# Precision: 0.4433
# Recall: 0.4317
# F1: 0.4289
